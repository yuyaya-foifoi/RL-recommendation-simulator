# %%
cd drive/MyDrive/JAIST/Research/RL/movie-lens-simulator
# Out:
# /content/drive/MyDrive/JAIST/Research/RL/movie-lens-simulator

# %%
# !make style
# !make setup
# Out:
# pip install -r ./requirements/style.txt
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting isort
#   Downloading isort-5.10.1-py3-none-any.whl (103 kB)
#      |████████████████████████████████| 103 kB 15.7 MB/s
# Collecting black
#   Downloading black-22.6.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 64.3 MB/s
# Collecting flake8
#   Downloading flake8-5.0.4-py2.py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 571 kB/s
# Collecting typed-ast>=1.4.2
#   Downloading typed_ast-1.5.4-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (843 kB)
#      |████████████████████████████████| 843 kB 67.8 MB/s
# Requirement already satisfied: typing-extensions>=3.10.0.0 in /usr/local/lib/python3.7/dist-packages (from black->-r ./requirements/style.txt (line 2)) (4.1.1)
# Collecting platformdirs>=2
#   Downloading platformdirs-2.5.2-py3-none-any.whl (14 kB)
# Collecting mypy-extensions>=0.4.3
#   Downloading mypy_extensions-0.4.3-py2.py3-none-any.whl (4.5 kB)
# Collecting click>=8.0.0
#   Downloading click-8.1.3-py3-none-any.whl (96 kB)
#      |████████████████████████████████| 96 kB 6.5 MB/s
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from black->-r ./requirements/style.txt (line 2)) (2.0.1)
# Collecting pathspec>=0.9.0
#   Downloading pathspec-0.9.0-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from click>=8.0.0->black->-r ./requirements/style.txt (line 2)) (4.12.0)
# Collecting mccabe<0.8.0,>=0.7.0
#   Downloading mccabe-0.7.0-py2.py3-none-any.whl (7.3 kB)
# Collecting importlib-metadata
#   Downloading importlib_metadata-4.2.0-py3-none-any.whl (16 kB)
# Collecting pyflakes<2.6.0,>=2.5.0
#   Downloading pyflakes-2.5.0-py2.py3-none-any.whl (66 kB)
#      |████████████████████████████████| 66 kB 5.4 MB/s
# Collecting pycodestyle<2.10.0,>=2.9.0
#   Downloading pycodestyle-2.9.1-py2.py3-none-any.whl (41 kB)
#      |████████████████████████████████| 41 kB 533 kB/s
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->click>=8.0.0->black->-r ./requirements/style.txt (line 2)) (3.8.1)
# Installing collected packages: importlib-metadata, typed-ast, pyflakes, pycodestyle, platformdirs, pathspec, mypy-extensions, mccabe, click, isort, flake8, black
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 4.12.0
#     Uninstalling importlib-metadata-4.12.0:
#       Successfully uninstalled importlib-metadata-4.12.0
#   Attempting uninstall: click
#     Found existing installation: click 7.1.2
#     Uninstalling click-7.1.2:
#       Successfully uninstalled click-7.1.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# markdown 3.4.1 requires importlib-metadata>=4.4; python_version < "3.10", but you have importlib-metadata 4.2.0 which is incompatible.
# flask 1.1.4 requires click<8.0,>=5.1, but you have click 8.1.3 which is incompatible.
# Successfully installed black-22.6.0 click-8.1.3 flake8-5.0.4 importlib-metadata-4.2.0 isort-5.10.1 mccabe-0.7.0 mypy-extensions-0.4.3 pathspec-0.9.0 platformdirs-2.5.2 pycodestyle-2.9.1 pyflakes-2.5.0 typed-ast-1.5.4
# isort src
# black src --line-length 79
# All done! ✨ 🍰 ✨
# 29 files left unchanged.
# flake8 src
# src/model/policy.py:90:27: W605 invalid escape sequence '\p'
# src/model/policy.py:93:12: W605 invalid escape sequence '\m'
# src/recommend/recommend_handler.py:145:26: E711 comparison to None should be 'if cond is None:'
# src/recommend/recommend_handler.py:268:38: E712 comparison to True should be 'if cond is True:' or 'if cond:'
# src/agent/actor_critic.py:3:1: F401 'torch.nn' imported but unused
# Makefile:4: recipe for target 'style' failed
# make: *** [style] Error 1
# pip install -r ./requirements/library.txt
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torchnet
#   Downloading torchnet-0.0.4.tar.gz (23 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from torchnet->-r ./requirements/library.txt (line 1)) (1.12.0+cu113)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from torchnet->-r ./requirements/library.txt (line 1)) (1.15.0)
# Collecting visdom
#   Downloading visdom-0.1.8.9.tar.gz (676 kB)
#      |████████████████████████████████| 676 kB 16.0 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->torchnet->-r ./requirements/library.txt (line 1)) (4.1.1)
# Requirement already satisfied: numpy>=1.8 in /usr/local/lib/python3.7/dist-packages (from visdom->torchnet->-r ./requirements/library.txt (line 1)) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from visdom->torchnet->-r ./requirements/library.txt (line 1)) (1.7.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from visdom->torchnet->-r ./requirements/library.txt (line 1)) (2.23.0)
# Requirement already satisfied: tornado in /usr/local/lib/python3.7/dist-packages (from visdom->torchnet->-r ./requirements/library.txt (line 1)) (5.1.1)
# Requirement already satisfied: pyzmq in /usr/local/lib/python3.7/dist-packages (from visdom->torchnet->-r ./requirements/library.txt (line 1)) (23.2.0)
# Collecting jsonpatch
#   Downloading jsonpatch-1.32-py2.py3-none-any.whl (12 kB)
# Collecting torchfile
#   Downloading torchfile-0.1.0.tar.gz (5.2 kB)
# Collecting websocket-client
#   Downloading websocket_client-1.3.3-py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 690 kB/s
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from visdom->torchnet->-r ./requirements/library.txt (line 1)) (7.1.2)
# Collecting jsonpointer>=1.9
#   Downloading jsonpointer-2.3-py2.py3-none-any.whl (7.8 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->visdom->torchnet->-r ./requirements/library.txt (line 1)) (2022.6.15)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->visdom->torchnet->-r ./requirements/library.txt (line 1)) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->visdom->torchnet->-r ./requirements/library.txt (line 1)) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->visdom->torchnet->-r ./requirements/library.txt (line 1)) (3.0.4)
# Building wheels for collected packages: torchnet, visdom, torchfile
#   Building wheel for torchnet (setup.py) ... done
#   Created wheel for torchnet: filename=torchnet-0.0.4-py3-none-any.whl size=29742 sha256=cc5d157347012d9dd7921865dc6200fca63878553054bf46828c15fbacf88a1a
#   Stored in directory: /root/.cache/pip/wheels/93/17/b3/86db1d93e9dae198813aa79831b403e4844d67986cf93894b5
#   Building wheel for visdom (setup.py) ... done
#   Created wheel for visdom: filename=visdom-0.1.8.9-py3-none-any.whl size=655250 sha256=c5717184d3a62ee78b71ffca863eca1aa1e2221ba32cf86b8ba85a1037974cc2
#   Stored in directory: /root/.cache/pip/wheels/2d/d1/9b/cde923274eac9cbb6ff0d8c7c72fe30a3da9095a38fd50bbf1
#   Building wheel for torchfile (setup.py) ... done
#   Created wheel for torchfile: filename=torchfile-0.1.0-py3-none-any.whl size=5709 sha256=6e36f1436993a0427d63f56101c375640c9f7c0b95fa97fc3ac402be374a7725
#   Stored in directory: /root/.cache/pip/wheels/ac/5c/3a/a80e1c65880945c71fd833408cd1e9a8cb7e2f8f37620bb75b
# Successfully built torchnet visdom torchfile
# Installing collected packages: jsonpointer, websocket-client, torchfile, jsonpatch, visdom, torchnet
# Successfully installed jsonpatch-1.32 jsonpointer-2.3 torchfile-0.1.0 torchnet-0.0.4 visdom-0.1.8.9 websocket-client-1.3.3

# %%
from src.data.movielens1M import LoadMovielens1M, PreprocessMovielens1M
from src.dataloader.movielens import MovieLensDataset
from src.dataloader.dataloader import get_MovieLensDataloaders
from src.model.embedding import Simulator, InitialRecommender
from src.trainer.rl_trainer import rl_trainer
from src.trainer.embedding_trainer import Embedding_Trainer
from src.recommend.recommend_handler import RecommendHandler
from src.evaluation.precision_oriented import PrecisionOrientedMetrics
from src.evaluation.diversity_oriented import DiversityOrientedMetrics

from configs.config import CFG_DICT
from src.utils.file_handler import File_Handler

from src.agent.actor_critic import ActorCriticAgent
from src.agent.soft_actor_critic import SAC


import numpy as np
import torch
import pandas as pd

file_handler = File_Handler(log_dir='AC/exp3')
logger = file_handler.make_logger_file('src')

# %%
load_rawML1M = LoadMovielens1M(path=CFG_DICT['DATASET']['PATH'])
raw_datas = load_rawML1M.load_data()

preprocessML1M = PreprocessMovielens1M(raw_datas)
preprocess_datas = preprocessML1M.apply_prepocess()

ratings, users, movies, histories = preprocess_datas

# %%
#preprocess_datas = ratings[ratings.UserID < 100], users, movies, histories
preprocess_datas = ratings, users, movies, histories

device = 'cuda'

recommend_handler = RecommendHandler(
    initial_data = preprocess_datas,
    topK = CFG_DICT['SIMULATION']['topK'],
    device = device,
    file_handler = file_handler,
    )

user_w = './log/train_usr/random_split/user_simulator.pkl'
user_simulator = Simulator(emb_size=CFG_DICT['USER_SIMULATOR']['DIM_EMB']).to(device)
user_simulator.load_state_dict(torch.load(user_w))

initial_recommender = InitialRecommender(emb_size=CFG_DICT['INITIAL_RECOMMENDER']['DIM_EMB']).to(device)

agent = ActorCriticAgent(device=device)

log_metrics = pd.DataFrame()


for time in np.arange(CFG_DICT['SIMULATION']['EPOCH']):

    ratings, _, _, _ = preprocess_datas

    logger.info('-'*50)
    logger.info('time : {}'.format(time))
    logger.info('data len : {}'.format(len(ratings)))


    ### recommend
    if time == 0:
        initial_recommender_datas = get_MovieLensDataloaders(
            model_type = 'INITIAL_RECOMMENDER',
            processed_data = preprocess_datas,
            data_split = 'random'
        )

        initial_recommender_trainer = Embedding_Trainer(
            model_type = 'INITIAL_RECOMMENDER',
            model = initial_recommender,
            loaders = initial_recommender_datas,
            device = device
            )

        initial_recommender = initial_recommender_trainer.train()
        file_handler.save(initial_recommender.state_dict(), 'initial_recommender_{}.pkl'.format(time))

        recommend_handler.register_models((initial_recommender, user_simulator))
        recommend_handler.recommend(time=time)
    
    else:

        agent, recommend_handler = rl_trainer(
            recommend_handler = recommend_handler,
            agent = agent,
            device = device,
            bs = CFG_DICT['REPLAY_BUFFER']['BS'],
            epoch = CFG_DICT['RL']['EPOCH']
        )

        recommend_handler.register_models((agent, user_simulator))
        recommend_handler.recommend(time=time)

    # evaluation
    pom = PrecisionOrientedMetrics(recommend_handler.pred_ratings, topK=CFG_DICT['SIMULATION']['topK'])

    MAP = pom.MAP()
    logger.info("MAP : {}".format(MAP))

    mean_Precision = pom.mean_Precision()
    logger.info("MEAN_PRECISION : {}".format(mean_Precision))

    MRR = pom.mrr()
    logger.info("MRR : {}".format(MRR))

    dom = DiversityOrientedMetrics(recommend_handler.pred_ratings, recommend_handler.ratings, topK=CFG_DICT['SIMULATION']['topK'])
    
    DIVERSITY = dom.diversity_score()
    logger.info("DIVERSITY : {}".format(DIVERSITY))

    SERENDIPITY = dom.serendipity_score()
    logger.info("SERENDIPITY : {}".format(SERENDIPITY))

    NOVELTY = dom.novelty_score()
    logger.info("NOVELTY : {}".format(NOVELTY))

    UNIQUENESS = dom.uniqueness_score()
    logger.info("UNIQUENESS : {}".format(UNIQUENESS))

    log_metrics = log_metrics.append({
        'MAP': MAP, 
        'MEAN_PRECISION': mean_Precision, 
        'MRR': MRR,
        'DIVERSITY': DIVERSITY, 
        'SERENDIPITY': SERENDIPITY, 
        'NOVELTY': NOVELTY,
        'UNIQUENESS' : UNIQUENESS,
        }, ignore_index=True)
    
    file_handler.save(log_metrics, 'log_metrics.csv')

    # update ratings
    recommend_handler.update_ratings()
    del preprocess_datas

    preprocess_datas = (recommend_handler.ratings, users, movies, recommend_handler.history)
# Out:
# INFO:src.model.embedding:Embedding size : 5
# INFO:src.model.embedding:Model Param : 19717
# INFO:src.model.embedding:Embedding size : 5
# INFO:src.model.embedding:Model Param : 2967
# INFO:src.model.policy:Policy Net, state dim : 3888
# INFO:src.model.policy:Policy Net, action dim : 3883
# INFO:src.model.value:Value Net, state dim : 3888
# INFO:src:--------------------------------------------------
# INFO:src:time : 0
# INFO:src:data len : 1000209
# INFO:src.trainer.embedding_trainer:Optimizer : adagrad
# INFO:src.trainer.embedding_trainer:Loss : cc
# INFO:src.trainer.embedding_trainer:INITIAL_RECOMMENDER training, epoch 0
# INFO:src.trainer.embedding_trainer:train / loss : 8.593142589159804e-05, auc : 0.5605842441629114
# INFO:src.trainer.embedding_trainer:val / loss : 0.0001695321552688256, auc : 0.5738238526923735
# INFO:src.trainer.embedding_trainer:test / loss : 0.000169257654924877, auc : 0.5722109120155293
# INFO:src:MAP : 0.43999409759764824
# INFO:src:MEAN_PRECISION : 0.32175496688741495
# INFO:src:MRR : 0.4980753311258286
# INFO:src:DIVERSITY : 490.1233200620718
# INFO:src:SERENDIPITY : 121.25041424138993
# INFO:src:NOVELTY : 5.858017271630329
# INFO:src:UNIQUENESS : 113.5
# INFO:src:--------------------------------------------------
# INFO:src:time : 1
# INFO:src:data len : 1060609
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/loss.py:922: UserWarning: Using a target size (torch.Size([4096, 4096])) that is different to the input size (torch.Size([4096, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.smooth_l1_loss(input, target, reduction=self.reduction, beta=self.beta)
# INFO:src:MAP : 0.348418244551315
# INFO:src:MEAN_PRECISION : 0.3450331125827814
# INFO:src:MRR : 0.3215034689372433
# INFO:src:DIVERSITY : 646.2160740642051
# INFO:src:SERENDIPITY : 100.97993656199979
# INFO:src:NOVELTY : 1.8954060447013077
# INFO:src:UNIQUENESS : 84.6
# INFO:src:--------------------------------------------------
# INFO:src:time : 2
# INFO:src:data len : 1066649
# INFO:src:MAP : 0.35059261298031563
# INFO:src:MEAN_PRECISION : 0.3548013245033109
# INFO:src:MRR : 0.31604711973089405
# INFO:src:DIVERSITY : 1176.6415532678923
# INFO:src:SERENDIPITY : 104.16230809467716
# INFO:src:NOVELTY : 0.22840768827361235
# INFO:src:UNIQUENESS : 83.4
# INFO:src:--------------------------------------------------
# INFO:src:time : 3
# INFO:src:data len : 1072689
# INFO:src:MAP : 0.3751971756172416
# INFO:src:MEAN_PRECISION : 0.3743377483443705
# INFO:src:MRR : 0.3503882844528537
# INFO:src:DIVERSITY : 1057.9852424925273
# INFO:src:SERENDIPITY : 99.81072075100019
# INFO:src:NOVELTY : -0.3601417323394383
# INFO:src:UNIQUENESS : 96.5
# INFO:src:--------------------------------------------------
# INFO:src:time : 4
# INFO:src:data len : 1078729
# INFO:src:MAP : 0.368615954107912
# INFO:src:MEAN_PRECISION : 0.35910596026490027
# INFO:src:MRR : 0.3512003311258274
# INFO:src:DIVERSITY : 1080.2024434365032
# INFO:src:SERENDIPITY : 102.6723464661633
# INFO:src:NOVELTY : -0.656480308128924
# INFO:src:UNIQUENESS : 93.8
# INFO:src:--------------------------------------------------
# INFO:src:time : 5
# INFO:src:data len : 1084769
# INFO:src:MAP : 0.35763895693487074
# INFO:src:MEAN_PRECISION : 0.3600993377483443
# INFO:src:MRR : 0.325658966677178
# INFO:src:DIVERSITY : 1091.4590517433733
# INFO:src:SERENDIPITY : 100.76550839497966
# INFO:src:NOVELTY : -1.1460983010212058
# INFO:src:UNIQUENESS : 81.5
# INFO:src:--------------------------------------------------
# INFO:src:time : 6
# INFO:src:data len : 1090809
# INFO:src:MAP : 0.38274959005554576
# INFO:src:MEAN_PRECISION : 0.37913907284768145
# INFO:src:MRR : 0.3591788867865021
# INFO:src:DIVERSITY : 1120.8839416679598
# INFO:src:SERENDIPITY : 101.06215964566155
# INFO:src:NOVELTY : -1.2389677313528598
# INFO:src:UNIQUENESS : 87.8
# INFO:src:--------------------------------------------------
# INFO:src:time : 7
# INFO:src:data len : 1096849
# INFO:src:MAP : 0.373479755251376
# INFO:src:MEAN_PRECISION : 0.3665562913907282
# INFO:src:MRR : 0.3537580153474187
# INFO:src:DIVERSITY : 1196.151495128504
# INFO:src:SERENDIPITY : 104.18847453797943
# INFO:src:NOVELTY : -1.425723827263223
# INFO:src:UNIQUENESS : 90.0
# INFO:src:--------------------------------------------------
# INFO:src:time : 8
# INFO:src:data len : 1102889
# INFO:src:MAP : 0.37565142191595763
# INFO:src:MEAN_PRECISION : 0.3763245033112579
# INFO:src:MRR : 0.342864369809734
# INFO:src:DIVERSITY : 1254.387413403046
# INFO:src:SERENDIPITY : 109.58385219487218
# INFO:src:NOVELTY : -1.6024654842945223
# INFO:src:UNIQUENESS : 90.6
# INFO:src:--------------------------------------------------
# INFO:src:time : 9
# INFO:src:data len : 1108929
# INFO:src:MAP : 0.36281638409594863
# INFO:src:MEAN_PRECISION : 0.36274834437086056
# INFO:src:MRR : 0.3358502838221378
# INFO:src:DIVERSITY : 1261.025888921886
# INFO:src:SERENDIPITY : 108.88357156233899
# INFO:src:NOVELTY : -1.814037664153808
# INFO:src:UNIQUENESS : 84.9
